# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
archivo = pd.read_csv('C:/Users/tomas/OneDrive/Escritorio/ORGA DE DATOS/train.csv')
archivo
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
plt.figure(dpi = 150)
plt.hist(archivo.SalePrice, color = "Green")
plt.title("Distribucion de indice del precio de venta")
plt.xlabel("Precio de venta")
plt.ylabel("Cantidad")
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
plt.figure(dpi = 150)
plt.title("Precio de venta segun la condicion de las calles")
sns.boxplot(data = archivo, x = "Street", y = "SalePrice", showfliers = False, palette="Greys")
plt.ylabel("Precio de venta")
plt.xlabel("Condicion de calle")
# Out:
# Text(0.5, 0, 'Condicion de calle')
